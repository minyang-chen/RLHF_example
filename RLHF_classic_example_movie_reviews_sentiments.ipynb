# %% [markdown]
# ## Reinforcement learning from human feedback (RLHF)
# Classic Example:
# Optimise GPT2 to produce positive IMDB movie reviews using a sentiment classifier as a reward function.

# %% [markdown]
# ### Environment Setup

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %pip install transformers trl

# %pip install langchain
# %pip install transformers
# %pip install accelerate
# %pip install xformers
# %pip install wandb

# %%
import torch
import pandas as pd
import wandb
from tqdm import tqdm
from transformers import pipeline, AutoTokenizer
from datasets import load_dataset
from trl import PPOTrainer, PPOConfig, AutoModelForCausalLMWithValueHead
from trl.core import LengthSampler

# %% [markdown]
# ### Training Config

# %%
config = PPOConfig(
    model_name="lvwerra/gpt2-imdb",
    learning_rate=1.41e-5,
    log_with="wandb",
)
sent_kwargs = {"return_all_scores": True, "function_to_apply": "none", "batch_size": 16}

## initialize if wandb specify and run on first time
wandb.init()
tqdm.pandas()
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# Finishing last run (ID:y22x0n34) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
#  View run <strong style="color:#cdcd00">charmed-wind-1</strong> at: <a href='https://wandb.ai/mychen76/uncategorized/runs/y22x0n34' target="_blank">https://wandb.ai/mychen76/uncategorized/runs/y22x0n34</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231010_050718-y22x0n34/logs</code>
# Successfully finished last run (ID:y22x0n34). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011115896133317923, max=1.0…
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/home/pop/mclab-finetune/wandb/run-20231010_050841-ijkvhuzv</code>
# Syncing run <strong><a href='https://wandb.ai/mychen76/uncategorized/runs/ijkvhuzv' target="_blank">proud-field-2</a></strong> to <a href='https://wandb.ai/mychen76/uncategorized' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/mychen76/uncategorized' target="_blank">https://wandb.ai/mychen76/uncategorized</a>
#  View run at <a href='https://wandb.ai/mychen76/uncategorized/runs/ijkvhuzv' target="_blank">https://wandb.ai/mychen76/uncategorized/runs/ijkvhuzv</a>

# %% [markdown]
# ### Prepare Training Dataset
# The IMDB dataset contains 50k movie review annotated with "positive"/"negative" feedback indicating the sentiment.

# %%
def collator(data):
    return dict((key, [d[key] for d in data]) for key in data[0])

def build_dataset(config, dataset_name="imdb", input_min_text_length=2, input_max_text_length=8):
    """
    Build dataset for training. This builds the dataset from `load_dataset`, one should
    customize this function to train the model on its own dataset.

    Args:
        dataset_name (`str`):
            The name of the dataset to be loaded.

    Returns:
        dataloader (`torch.utils.data.DataLoader`):
            The dataloader for the dataset.
    """
    tokenizer = AutoTokenizer.from_pretrained(config.model_name)
    tokenizer.pad_token = tokenizer.eos_token
    # load imdb with datasets
    ds = load_dataset(dataset_name, split="train")
    ds = ds.rename_columns({"text": "review"})
    # fixed the lenght to 200 characters 
    ds = ds.filter(lambda x: len(x["review"]) > 200, batched=False)    
    input_size = LengthSampler(input_min_text_length, input_max_text_length)

    def tokenize(sample):
        sample["input_ids"] = tokenizer.encode(sample["review"])[: input_size()]
        sample["query"] = tokenizer.decode(sample["input_ids"])
        return sample

    ds = ds.map(tokenize, batched=False)
    ds.set_format(type="torch")
    return ds

# %%
dataset = build_dataset(config)
# Out:
# Map:   0%|          | 0/24895 [00:00<?, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (1168 > 1024). Running this sequence through the model will result in indexing errors

# %% [markdown]
# ### Load Models

# %%
## optimization model
target_model = AutoModelForCausalLMWithValueHead.from_pretrained(config.model_name)
## reference use by DPO to calculate the Kl-divergence
reference_model = AutoModelForCausalLMWithValueHead.from_pretrained(config.model_name)
## tokenizer
tokenizer = AutoTokenizer.from_pretrained(config.model_name)
tokenizer.pad_token = tokenizer.eos_token

# %% [markdown]
# ### PPOTrainer

# %%
ppo_trainer = PPOTrainer(config, target_model, reference_model, tokenizer, dataset=dataset, data_collator=collator)
# Out:
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/accelerate/accelerator.py:382: UserWarning: `log_with=wandb` was passed but no supported trackers are currently installed.
#   warnings.warn(f"`log_with={log_with}` was passed but no supported trackers are currently installed.")

# %% [markdown]
# ### Get Reward Model
# Use BERT classifier fine-tuned on the IMDB dataset to self generate Rewards

# %%
device = ppo_trainer.accelerator.device
if ppo_trainer.accelerator.num_processes == 1:
    device = 0 if torch.cuda.is_available() else "cpu"  # to avoid a `pipeline` bug
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/735 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/333 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
sentiment_pipe = pipeline("sentiment-analysis", model="lvwerra/distilbert-imdb", device=device)

# %% [markdown]
# The model outputs are the logits for the negative and positive class. We will use the logits for positive class as a reward signal for the language model.

# %%
text = "this movie was really bad!!"
sentiment_pipe(text, **sent_kwargs)
# Out:
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:105: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# [[{'label': 'NEGATIVE', 'score': 2.3350486755371094},
#   {'label': 'POSITIVE', 'score': -2.726576566696167}]]

# %%
text = "this movie was really good!!"
sentiment_pipe(text, **sent_kwargs)
# Out:
# [[{'label': 'NEGATIVE', 'score': -2.2947897911071777},
#   {'label': 'POSITIVE', 'score': 2.557039737701416}]]

# %% [markdown]
# ## Train target optimization model

# %%
gen_kwargs = {"min_length": -1, "top_k": 0.0, "top_p": 1.0, "do_sample": True, "pad_token_id": tokenizer.eos_token_id}

# %% [markdown]
# ### Steps
# 1. Get the responses from the target policy model
# 2. Get sentiments for query/responses for reward calculation
# 3. Optimize policy with PPO using the (query, response, reward) triplet

# %%
# %%time
output_min_length = 4
output_max_length = 16
output_length_sampler = LengthSampler(output_min_length, output_max_length)

generation_kwargs = {
    "min_length": -1,
    "top_k": 0.0,
    "top_p": 1.0,
    "do_sample": True,
    "pad_token_id": tokenizer.eos_token_id,
}
## training loop
for epoch, batch in tqdm(enumerate(ppo_trainer.dataloader)):
    query_tensors = batch["input_ids"]

    ### Gather response from gpt2
    response_tensors = []
    for query in query_tensors:
        gen_len = output_length_sampler()
        generation_kwargs["max_new_tokens"] = gen_len
        response = ppo_trainer.generate(query, **generation_kwargs)
        response_tensors.append(response.squeeze()[-gen_len:])
    batch["response"] = [tokenizer.decode(r.squeeze()) for r in response_tensors]

    ### calculate sentiment score
    texts = [q + r for q, r in zip(batch["query"], batch["response"])]
    pipe_outputs = sentiment_pipe(texts, **sent_kwargs)
    rewards = [torch.tensor(output[1]["score"]) for output in pipe_outputs]

    ### Run PPO step
    stats = ppo_trainer.step(query_tensors, response_tensors, rewards)
    ppo_trainer.log_stats(stats, batch, rewards)
# Out:
# 0it [00:00, ?it/s]You're using a GPT2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (22.42) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (16.58) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (12.46) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (22.29) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (12.49) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (11.78) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (17.78) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (14.58) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (11.89) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (33.81) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (22.22) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 1it [01:20, 80.98s/it]/miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (23.07) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (24.12) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (11.13) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (367.49) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (79.75) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (15.75) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (13.98) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (12.81) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (76.59) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (18.37) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (23.36) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (23.40) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (372.32) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (22.40) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (23.57) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (18.69) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (14.38) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (373.87) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (14.52) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (75.28) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (22.89) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (12.90) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 2it [02:45, 83.28s/it]/miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (21.02) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (32.94) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (22.28) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (18.94) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (24.73) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (29.73) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (70.32) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (17.87) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (16.08) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (20.02) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (14.28) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (62.88) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (29.91) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (17.12) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (19.90) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (20.53) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (29.15) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (18.65) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (57.14) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (31.02) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (66.97) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (19.66) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (19.19) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (11.38) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (14.67) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (20.01) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (19.05) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (24.53) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (26.17) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (23.62) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (16.88) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (33.42) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (18.62) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (67.98) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (15.18) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (12.10) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (19.17) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (19.72) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 3it [04:11, 84.24s/it]/miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (89.65) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (13.51) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (697.96) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (15.64) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (12.96) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (13.92) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (11.82) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (15.23) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (660.42) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (66.79) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (11.26) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (11.25) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (74.41) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (669.03) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (14.23) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (18.90) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (12.02) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (17.36) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (14.95) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 4it [05:35, 84.07s/it]/miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (68.42) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (25.10) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (12.65) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (23.32) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (14.44) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (20.48) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (20.05) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (23.42) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (30.02) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (11.53) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (11.11) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (25.88) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (51.84) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (26.38) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (24.57) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (12.00) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (13.29) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (230.78) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (84.72) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (27.21) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (28.42) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (60.72) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 5it [06:59, 84.17s/it]/miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (108.26) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (38.64) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (12.08) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (12.06) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (110.53) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (41.62) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (12.40) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (13.90) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (11.49) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (15.17) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (12.23) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (129.39) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (42.83) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (167.54) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 6it [08:25, 84.66s/it]/miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (57.42) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (15.01) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (10.50) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (28.35) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (19.04) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (664.02) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (14.61) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (698.10) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (32.30) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (10.72) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (21.61) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (19.06) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (19.68) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (13.96) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (55.63) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (11.01) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (719.14) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (17.60) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (13.82) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (56.25) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (31.12) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 7it [09:50, 84.88s/it]/miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (527.30) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (36.59) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (177.47) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (98.09) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (10.52) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (13.94) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (172.10) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (433.21) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (10.27) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (96.48) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (175.39) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (34.67) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (174.22) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (96.45) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (191.75) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (35.29) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (440.38) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (10.70) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (12.62) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (97.66) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 8it [11:16, 85.14s/it]/miniconda/envs/llama2tune/lib/python3.10/site-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (17.85) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (19.36) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (65.28) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (16.17) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (15.19) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (16.31) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (53.79) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (27.43) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (17.63) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (15.13) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (17.91) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (71.29) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (13.10) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (12.28) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (56.15) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (56.24) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (55.26) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (17.04) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (1415.54) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (17.97) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (28.13) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (11.59) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (17.99) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (16.89) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (28.79) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 9it [12:41, 85.14s/it]/miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (10.67) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (79.11) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (20.65) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (81.37) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (46.74) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (12.35) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (22.53) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (13.24) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (20.66) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (45.33) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (13.43) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (12.01) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (88.89) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (12.60) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (13.25) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (95.08) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (99.44) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (12.22) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (94.73) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (24.31) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (20.74) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (15.94) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (12.47) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (49.42) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (14.15) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 10it [14:06, 85.09s/it]/miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (36.16) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (15.30) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (51.53) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (14.22) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (64.42) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (15.73) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (39.51) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (13.83) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (39.11) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (14.54) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (52.23) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (37.63) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (20.17) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (13.78) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (25.30) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (12.91) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (35.63) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (77.55) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (10.06) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (14.02) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (10.21) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (21.48) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (11.27) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (26.23) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (20.75) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# ...
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (38.01) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (58.71) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (275.37) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 92it [2:09:53, 84.28s/it]/miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (23.23) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (20.12) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (97.61) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (19.82) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (18.77) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (126.93) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (15030.69) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (13344.39) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (12.17) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (18.67) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (126.81) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (18.78) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (97.07) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (25.45) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (96.96) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (25.25) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (13240.70) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (126.64) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (20.42) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (18.95) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 93it [2:11:17, 84.14s/it]/miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (20.97) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (25.23) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (17.26) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (114.79) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (29.37) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (29.20) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (12.45) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (29.21) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (115.25) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (27.35) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 94it [2:12:42, 84.21s/it]/miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (34.97) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (10.73) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (289.36) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (87.33) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (111.43) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (79.13) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (292.52) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (109.87) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (26.07) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (25.86) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (82.65) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (109.10) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (297.03) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (16.56) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (26.11) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (16.22) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 95it [2:14:06, 84.41s/it]/miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (10.69) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (964.61) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (158.46) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (11.67) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (176.62) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (1174.06) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (128.77) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (153.40) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (11.29) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (18.28) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (122.22) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (1160.58) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (166.56) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 96it [2:15:31, 84.54s/it]/miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (14.41) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (1964.47) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (15143.73) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (26.10) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (21.25) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (39.08) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (29.78) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (39.38) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (24.82) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (13257.65) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (1824.71) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (24.86) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (21.76) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (39.05) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (22.24) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (25.08) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (1720.53) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (14248.57) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1164: UserWarning: The average ratio of batch (29.82) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 97it [2:16:56, 84.70s/it]

# %% [markdown]
# ### Validate Trained Model
# Let's inspect some examples from the IMDB dataset. We can use `reference_model` to compare the optimized model `target model` against the model before optimisation.

# %%
#### get samples from dataset
bs = 16
result_data = dict()
dataset.set_format("pandas")
df_batch = dataset[:].sample(bs)
result_data["query"] = df_batch["query"].tolist()
query_tensors = df_batch["input_ids"].tolist()

response_tensors_ref, response_tensors = [], []

#### get response optimized model and reference model
for i in range(bs):
    gen_len = output_length_sampler()
    output = reference_model.generate(
        torch.tensor(query_tensors[i]).unsqueeze(dim=0).to(device), max_new_tokens=gen_len, **gen_kwargs
    ).squeeze()[-gen_len:]
    
    response_tensors_ref.append(output)
    output = target_model.generate(
        torch.tensor(query_tensors[i]).unsqueeze(dim=0).to(device), max_new_tokens=gen_len, **gen_kwargs
    ).squeeze()[-gen_len:]
    response_tensors.append(output)

#### decode responses
result_data["response (before)"] = [tokenizer.decode(response_tensors_ref[i]) for i in range(bs)]
result_data["response (after)"] = [tokenizer.decode(response_tensors[i]) for i in range(bs)]

#### sentiment analysis of query/response pairs before/after
texts = [q + r for q, r in zip(result_data["query"], result_data["response (before)"])]
result_data["rewards (before)"] = [output[1]["score"] for output in sentiment_pipe(texts, **sent_kwargs)]

texts = [q + r for q, r in zip(result_data["query"], result_data["response (after)"])]
result_data["rewards (after)"] = [output[1]["score"] for output in sentiment_pipe(texts, **sent_kwargs)]

# store results in a dataframe
df_results = pd.DataFrame(result_data)
df_results
# Out:
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:105: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# /miniconda/envs/llama2tune/lib/python3.10/site-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#                                  query  \
# 0                      The Great Carus
# 1                              Acclaim
# 2                     Corny! I love it
# 3         Just watched this early Bugs
# 4   Another day stuck indoors, another
# 5          Morgan Freeman and Paz Vega
# 6                            This 1981
# 7            Liked Stanley & Iris very
# 8         The extended nuclear family,
# 9              The only thing that "An
# 10                  I had the pleasure
# 11               Well it's been a long
# 12                        A bit quirky
# 13       I guess I only have myself to
# 14        The only way to get anything
# 15        Fritz Lang's German medieval
#
#                                     response (before)  \
# 0           The Great Carusaville 1913)"<|endoftext|>
# 1    ed and successful tourist film producer/director
# 2   . Submissions please. Keep my vote miner Trent...
# 3                           Bunny episode and enjoyed
# 4    one of Kirk's doctors conducts an autopsy on ...
# 5                               ) wondering what they
# 6                                         film: limp,
# 7                             much and being heartly,
# 8        the musical "The Parsons Family," there will
# 9                        Root for Hope" could qualify
# 10                                to sit through "Gim
# 11           time since I've seen this, but the movie
# 12                                    and straight-to
# 13  I guess I only have myself to blame.<|endoftext|>
# 14                         positive out of Weight Wat
# 15   color photography and the welcome European sc...
#
#                                      response (after)  rewards (before)  \
# 0          co was highly talented and even as a first          0.146418
# 1        ed by the director of the standard Hollywood          2.257848
# 2                      Corny! I love it!<|endoftext|>          2.124160
# 3                                     flick and it is          2.131294
# 4    flyingwww film showing flashes of the series ...         -0.280814
# 5                           are so fantastic watching          0.716412
# 6                                       is one of the         -2.326047
# 7                     much! The photography really is          2.502383
# 8    the beautiful daughter and daughter's sibling...          0.562979
# 9                                  early 20s tale" is         -1.813615
# 10                              to see it... I really          0.091263
# 11          time and this is one of the best movies I          0.726745
# 12                                  , but I certainly          1.707787
# 13   compare these films but I highly recommend it...         -1.513157
# 14                                  wrong is to see "         -1.963960
# 15        June film is one of the best I've ever seen          1.979629
#
#     rewards (after)
# 0          2.368905
# 1          2.317222
# 2          2.527075
# 3          1.496077
# 4          2.411691
# 5          2.640832
# 6          1.508976
# 7          2.677704
# 8          1.592980
# 9         -0.880475
# 10         1.982445
# 11         2.764468
# 12         1.513810
# 13         2.590421
# 14        -0.484065
# 15         2.706583

# %% [markdown]
# Looking at the reward mean/median of the generated sequences we observe a significant difference.

# %% [markdown]
# ### Save model and Push to Hub

# %%
target_model.save_pretrained("mychen76/gpt2-imdb-ppo-v1", push_to_hub=True)
tokenizer.save_pretrained("mychen76/gpt2-imdb-ppo-v1", push_to_hub=True)
# Out:
# pytorch_model.bin:   0%|          | 0.00/498M [00:00<?, ?B/s]
# ('mychen76/gpt2-imdb-ppo-v1/tokenizer_config.json',
#  'mychen76/gpt2-imdb-ppo-v1/special_tokens_map.json',
#  'mychen76/gpt2-imdb-ppo-v1/vocab.json',
#  'mychen76/gpt2-imdb-ppo-v1/merges.txt',
#  'mychen76/gpt2-imdb-ppo-v1/added_tokens.json',
#  'mychen76/gpt2-imdb-ppo-v1/tokenizer.json')
